# %%
# import lux
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./data/train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pip uninstall lux
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping lux as it is not installed.

# %%
# 3d py error ata ha

# %%
data = [[[1, 'Ali','A.I',1500],
       [2, 'Asif','A.I',1500],
       [3, 'Hamza','A.I',3000],
       [4, 'Kashif','AIOT',np.nan],
       [5, 'Ali','A.I',3000]]]
data
df1 = pd.DataFrame(data,columns=['ID',"Name","Course","Fee"])
df1
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     563     try:
# --> 564         columns = _validate_or_indexify_columns(content, columns)
#     565         result = _convert_object_array(content, dtype=dtype, coerce_float=coerce_float)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _validate_or_indexify_columns(content, columns)
#     687             # caller's responsibility to check for this...
# --> 688             raise AssertionError(
#     689                 f"{len(columns)} columns passed, passed data had "
#
# AssertionError: 4 columns passed, passed data had 5 columns
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data = [[1, 'Ali','A.I',1500],
       [2, 'Asif','A.I',1500],
       [3, 'Hamza','A.I',3000],
       [4, 'Kashif','AIOT',np.nan],
       [5, 'Ali','A.I',3000]]
data
df1 = pd.DataFrame(data,columns=['ID',"Name","Course","Fee"])
df1
# Out:
#    ID    Name Course     Fee
# 0   1     Ali    A.I  1500.0
# 1   2    Asif    A.I  1500.0
# 2   3   Hamza    A.I  3000.0
# 3   4  Kashif   AIOT     NaN
# 4   5     Ali    A.I  3000.0

# %%
df1.columns
# Out:
# Index(['ID', 'Name', 'Course', 'Fee'], dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df1.values
# Out:
# array([[1, 'Ali', 'A.I', 1500.0],
#        [2, 'Asif', 'A.I', 1500.0],
#        [3, 'Hamza', 'A.I', 3000.0],
#        [4, 'Kashif', 'AIOT', nan],
#        [5, 'Ali', 'A.I', 3000.0]], dtype=object)

# %%
df1['total'] = 0
df1
# Out:
#    ID    Name Course     Fee  total
# 0   1     Ali    A.I  1500.0      0
# 1   2    Asif    A.I  1500.0      0
# 2   3   Hamza    A.I  3000.0      0
# 3   4  Kashif   AIOT     NaN      0
# 4   5     Ali    A.I  3000.0      0

# %%
df1.Timing = "100K" # didn't add the value
df1
# Out:
#    ID    Name Course     Fee  total
# 0   1     Ali    A.I  1500.0      0
# 1   2    Asif    A.I  1500.0      0
# 2   3   Hamza    A.I  3000.0      0
# 3   4  Kashif   AIOT     NaN      0
# 4   5     Ali    A.I  3000.0      0

# %% [markdown]
# ### Apply General Functions on series

# %% [raw]
# dataframe.columnname.functionName()

# %%
df1.Name.unique()
# Out:
# array(['Ali', 'Asif', 'Hamza', 'Kashif'], dtype=object)

# %%
df1.Course.unique()
# Out:
# array(['A.I', 'AIOT'], dtype=object)

# %%
for v in df1.Course.unique():
    print(v, len(df1[df1.Course == v]))
# Out:
# A.I 4
# AIOT 1

# %%
df1.Course.value_counts()
# Out:
# A.I     4
# AIOT    1
# Name: Course, dtype: int64

# %% [markdown]
# ### how to aply dearch function on dF

# %%
df1.Course == 'A.I'
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# Name: Course, dtype: bool

# %%
df1[df1.Course == 'A.I']
# Out:
#    ID   Name Course     Fee  total
# 0   1    Ali    A.I  1500.0      0
# 1   2   Asif    A.I  1500.0      0
# 2   3  Hamza    A.I  3000.0      0
# 4   5    Ali    A.I  3000.0      0

# %%
len(df1[df1.Course == 'A.I'])
# Out:
# 4

# %%
df1[(df1.Course == 'A.I') & (df1.Fee > 1500)]
# Out:
#    ID   Name Course     Fee  total
# 2   3  Hamza    A.I  3000.0      0
# 4   5    Ali    A.I  3000.0      0

# %%
data = [[1, 'Ali','CNC',1500],
       [2, 'Asif','A.I',1500],
       [3, 'Hamza','A.I',3000],
       [4, 'Kashif','AIOT',np.nan],
       [5, 'Ali','CNC',3000]]
data
df = pd.DataFrame(data,columns=['ID',"Name","Course","Fee"])
df
# Out:
#    ID    Name Course     Fee
# 0   1     Ali    CNC  1500.0
# 1   2    Asif    A.I  1500.0
# 2   3   Hamza    A.I  3000.0
# 3   4  Kashif   AIOT     NaN
# 4   5     Ali    CNC  3000.0

# %%
df['abc'] = df[(df.Course == 'A.I') & (df.Fee == 1500)] # error arises
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'abc'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
# ...

# %% [raw]
# Task: CNIC, Ibank, Network , passport

# %% [raw]
# #dataframe.column.apply() (pass user define function)
# #dataframe.column.unique()
# #dataframe.column.map() (pass dictionary (find key and replace with value))
# #dataframe.column.value_counts()
# #dataframe.columns.sum() #min,max,mean,std

# %%
d1 = {'A.I':1,
     "AIOT": 2,
     "CNC": 3,
     np.nan:0}
df.Course.map(d1)
# Out:
# 0    3
# 1    1
# 2    1
# 3    2
# 4    3
# Name: Course, dtype: int64

# %%
df.Course.unique()
# Out:
# array(['CNC', 'A.I', 'AIOT'], dtype=object)

# %% [markdown]
# ### map method

# %%
d2 = {}
for i,v in enumerate(df.Course.unique()):
    d2[v]= i
print(d2)
# Out:
# {'CNC': 0, 'A.I': 1, 'AIOT': 2}

# %%
df['updated_course_code'] = df.Course.map(d2)
df
# Out:
#    ID    Name Course     Fee  updated_course_code
# 0   1     Ali    CNC  1500.0                    0
# 1   2    Asif    A.I  1500.0                    1
# 2   3   Hamza    A.I  3000.0                    1
# 3   4  Kashif   AIOT     NaN                    2
# 4   5     Ali    CNC  3000.0                    0

# %%
d2 = {}
for i,v in enumerate(df.Course.unique()):
    d2[v]= i + 3 # encrption
print(d2)
# Out:
# {'CNC': 3, 'A.I': 4, 'AIOT': 5}

# %%
df['updated_course_code'] = df.Course.map(d2)
df
# Out:
#    ID    Name Course     Fee  updated_course_code
# 0   1     Ali    CNC  1500.0                    3
# 1   2    Asif    A.I  1500.0                    4
# 2   3   Hamza    A.I  3000.0                    4
# 3   4  Kashif   AIOT     NaN                    5
# 4   5     Ali    CNC  3000.0                    3

# %%
df['new_course'] = df.Course.map(d2)

# %% [markdown]
# ## Apply method

# %%
def add_fees(x):
    if x == 'A.I': return 100
    elif x == 'AIOT': return 200
    elif x == 'CNC' : return 300
    else : return 0

# %%
df['fee'] = df.Course.apply(add_fees)
df
# Out:
#    ID    Name Course     Fee  updated_course_code  new_course  fee
# 0   1     Ali    CNC  1500.0                    3           3  300
# 1   2    Asif    A.I  1500.0                    4           4  100
# 2   3   Hamza    A.I  3000.0                    4           4  100
# 3   4  Kashif   AIOT     NaN                    5           5  200
# 4   5     Ali    CNC  3000.0                    3           3  300

# %% [markdown]
# ### Marksheet

# %%
df2 = pd.DataFrame(np.random.randint(1,101, size=(5,5)), 
                   columns=["A","B","C","D","E"])
df2
# Out:
#     A   B   C   D   E
# 0  63   1  35  74  29
# 1  93  50   1  74  49
# 2  32  84  83  53  18
# 3  12  39  67  26  93
# 4  69  35  62  95  33

# %% [raw]
# pd.concat([df1,df2,df3..], axis=0) # axix = 0 or Y # axis 1 or X

# %%
df = pd.concat([df1,df2])
df
# Out:
#     ID    Name Course     Fee  total     A     B     C     D     E
# 0  1.0     Ali    A.I  1500.0    0.0   NaN   NaN   NaN   NaN   NaN
# 1  2.0    Asif    A.I  1500.0    0.0   NaN   NaN   NaN   NaN   NaN
# 2  3.0   Hamza    A.I  3000.0    0.0   NaN   NaN   NaN   NaN   NaN
# 3  4.0  Kashif   AIOT     NaN    0.0   NaN   NaN   NaN   NaN   NaN
# 4  5.0     Ali    A.I  3000.0    0.0   NaN   NaN   NaN   NaN   NaN
# 0  NaN     NaN    NaN     NaN    NaN  63.0   1.0  35.0  74.0  29.0
# 1  NaN     NaN    NaN     NaN    NaN  93.0  50.0   1.0  74.0  49.0
# 2  NaN     NaN    NaN     NaN    NaN  32.0  84.0  83.0  53.0  18.0
# 3  NaN     NaN    NaN     NaN    NaN  12.0  39.0  67.0  26.0  93.0
# 4  NaN     NaN    NaN     NaN    NaN  69.0  35.0  62.0  95.0  33.0

# %%
df = pd.concat([df1,df2], axis = 1)
df
# Out:
#    ID    Name Course     Fee  total   A   B   C   D   E
# 0   1     Ali    A.I  1500.0      0  63   1  35  74  29
# 1   2    Asif    A.I  1500.0      0  93  50   1  74  49
# 2   3   Hamza    A.I  3000.0      0  32  84  83  53  18
# 3   4  Kashif   AIOT     NaN      0  12  39  67  26  93
# 4   5     Ali    A.I  3000.0      0  69  35  62  95  33

# %%
df['total'] = df.A + df.B + df.C + df.D + df.E
df
# Out:
#    ID    Name Course     Fee  total   A   B   C   D   E
# 0   1     Ali    A.I  1500.0    202  63   1  35  74  29
# 1   2    Asif    A.I  1500.0    267  93  50   1  74  49
# 2   3   Hamza    A.I  3000.0    270  32  84  83  53  18
# 3   4  Kashif   AIOT     NaN    237  12  39  67  26  93
# 4   5     Ali    A.I  3000.0    294  69  35  62  95  33

# %%
df['percentage'] = (df.total)*100/500
df
# Out:
#    ID    Name Course     Fee  total   A   B   C   D   E  percentage
# 0   1     Ali    A.I  1500.0    202  63   1  35  74  29        40.4
# 1   2    Asif    A.I  1500.0    267  93  50   1  74  49        53.4
# 2   3   Hamza    A.I  3000.0    270  32  84  83  53  18        54.0
# 3   4  Kashif   AIOT     NaN    237  12  39  67  26  93        47.4
# 4   5     Ali    A.I  3000.0    294  69  35  62  95  33        58.8

# %% [markdown]
# #### Using iloc

# %%
df.iloc[1:3,:]
# Out:
#    ID   Name Course     Fee  total   A   B   C   D   E  percentage
# 1   2   Asif    A.I  1500.0    267  93  50   1  74  49        53.4
# 2   3  Hamza    A.I  3000.0    270  32  84  83  53  18        54.0

# %%
df.iloc[1:3,5:-1]
# Out:
#     A   B   C   D   E
# 1  93  50   1  74  49
# 2  32  84  83  53  18

# %%
df.loc[:,'A':'E']
# Out:
#     A   B   C   D   E
# 0  63   1  35  74  29
# 1  93  50   1  74  49
# 2  32  84  83  53  18
# 3  12  39  67  26  93
# 4  69  35  62  95  33

# %%
df.loc[:,'A':'E'].sum() # we want axis 1 so
# Out:
# A    269
# B    209
# C    248
# D    322
# E    222
# dtype: int64

# %%
df['total_1'] = df.loc[:,'A':'E'].sum(axis = 1)
df
# Out:
#    ID    Name Course     Fee  total   A   B   C   D   E  percentage  total_1
# 0   1     Ali    A.I  1500.0    202  63   1  35  74  29        40.4      202
# 1   2    Asif    A.I  1500.0    267  93  50   1  74  49        53.4      267
# 2   3   Hamza    A.I  3000.0    270  32  84  83  53  18        54.0      270
# 3   4  Kashif   AIOT     NaN    237  12  39  67  26  93        47.4      237
# 4   5     Ali    A.I  3000.0    294  69  35  62  95  33        58.8      294

# %%
df.loc[:,::-1]
# Out:
#    total_1  percentage   E   D   C   B   A  total     Fee Course    Name  ID
# 0      202        40.4  29  74  35   1  63    202  1500.0    A.I     Ali   1
# 1      267        53.4  49  74   1  50  93    267  1500.0    A.I    Asif   2
# 2      270        54.0  18  53  83  84  32    270  3000.0    A.I   Hamza   3
# 3      237        47.4  93  26  67  39  12    237     NaN   AIOT  Kashif   4
# 4      294        58.8  33  95  62  35  69    294  3000.0    A.I     Ali   5

# %%
df.loc[:,'E':'A':-1]
# Out:
#     E   D   C   B   A
# 0  29  74  35   1  63
# 1  49  74   1  50  93
# 2  18  53  83  84  32
# 3  93  26  67  39  12
# 4  33  95  62  35  69

# %%
df['percentage'] = df.loc[:,'A':'E'].sum(axis = 1)*100/500
# df['percentage'] = (df.A + df.B + df.C + df.D + df.E)*100/500
df
# Out:
#    ID    Name Course     Fee  total   A   B   C   D   E  percentage  total_1
# 0   1     Ali    A.I  1500.0    202  63   1  35  74  29        40.4      202
# 1   2    Asif    A.I  1500.0    267  93  50   1  74  49        53.4      267
# 2   3   Hamza    A.I  3000.0    270  32  84  83  53  18        54.0      270
# 3   4  Kashif   AIOT     NaN    237  12  39  67  26  93        47.4      237
# 4   5     Ali    A.I  3000.0    294  69  35  62  95  33        58.8      294

# %%
def grade(p):
    if p>= 80: return 'A+'
    elif p>= 70 : return 'A'
    elif p>= 60 : return 'B'
    elif p>= 50 : return 'C'
    else: return 'Fail'

# %%
df['Grade'] = df.percentage.map(grade)
df
# Out:
#    ID    Name Course     Fee  total   A   B   C   D   E  percentage  total_1  \
# 0   1     Ali    A.I  1500.0    202  63   1  35  74  29        40.4      202
# 1   2    Asif    A.I  1500.0    267  93  50   1  74  49        53.4      267
# 2   3   Hamza    A.I  3000.0    270  32  84  83  53  18        54.0      270
# 3   4  Kashif   AIOT     NaN    237  12  39  67  26  93        47.4      237
# 4   5     Ali    A.I  3000.0    294  69  35  62  95  33        58.8      294
#
#   Grade
# 0  Fail
# 1     C
# 2     C
# 3  Fail
# 4     C

# %%
del df['total_1']

# %%
df
# Out:
#    ID    Name Course     Fee  total   A   B   C   D   E  percentage Grade
# 0   1     Ali    A.I  1500.0    202  63   1  35  74  29        40.4  Fail
# 1   2    Asif    A.I  1500.0    267  93  50   1  74  49        53.4     C
# 2   3   Hamza    A.I  3000.0    270  32  84  83  53  18        54.0     C
# 3   4  Kashif   AIOT     NaN    237  12  39  67  26  93        47.4  Fail
# 4   5     Ali    A.I  3000.0    294  69  35  62  95  33        58.8     C

# %% [markdown]
# ### Sort Data
# - index
# -Value

# %%
pd.DataFrame(df.Course.value_counts())
# Out:
#       Course
# A.I        4
# AIOT       1

# %%
df.sort_index()  # row Indexes
# Out:
#    ID    Name Course     Fee  total   A   B   C   D   E  percentage Grade
# 0   1     Ali    A.I  1500.0    202  63   1  35  74  29        40.4  Fail
# 1   2    Asif    A.I  1500.0    267  93  50   1  74  49        53.4     C
# 2   3   Hamza    A.I  3000.0    270  32  84  83  53  18        54.0     C
# 3   4  Kashif   AIOT     NaN    237  12  39  67  26  93        47.4  Fail
# 4   5     Ali    A.I  3000.0    294  69  35  62  95  33        58.8     C

# %%
df.sort_index(axis = 1)  # column indexing
# Out:
#     A   B   C Course   D   E     Fee Grade  ID    Name  percentage  total
# 0  63   1  35    A.I  74  29  1500.0  Fail   1     Ali        40.4    202
# 1  93  50   1    A.I  74  49  1500.0     C   2    Asif        53.4    267
# 2  32  84  83    A.I  53  18  3000.0     C   3   Hamza        54.0    270
# 3  12  39  67   AIOT  26  93     NaN  Fail   4  Kashif        47.4    237
# 4  69  35  62    A.I  95  33  3000.0     C   5     Ali        58.8    294

# %%
a = df.groupby(['Course'])[['A','B','C']].agg(['count', 'sum'])
a.sort_index(axis = 1 ,ascending= False)
# Out:
#           C          B          A
#         sum count  sum count  sum count
# Course
# A.I     181     4  170     4  257     4
# AIOT     67     1   39     1   12     1

# %%
df.sort_index(axis = 1, ascending= False)
# Out:
#    total  percentage    Name  ID Grade     Fee   E   D Course   C   B   A
# 0    202        40.4     Ali   1  Fail  1500.0  29  74    A.I  35   1  63
# 1    267        53.4    Asif   2     C  1500.0  49  74    A.I   1  50  93
# 2    270        54.0   Hamza   3     C  3000.0  18  53    A.I  83  84  32
# 3    237        47.4  Kashif   4  Fail     NaN  93  26   AIOT  67  39  12
# 4    294        58.8     Ali   5     C  3000.0  33  95    A.I  62  35  69

# %%
df.sort_index(axis = 1, ascending= True)
# Out:
#     A   B   C Course   D   E     Fee Grade  ID    Name  percentage  total
# 0  63   1  35    A.I  74  29  1500.0  Fail   1     Ali        40.4    202
# 1  93  50   1    A.I  74  49  1500.0     C   2    Asif        53.4    267
# 2  32  84  83    A.I  53  18  3000.0     C   3   Hamza        54.0    270
# 3  12  39  67   AIOT  26  93     NaN  Fail   4  Kashif        47.4    237
# 4  69  35  62    A.I  95  33  3000.0     C   5     Ali        58.8    294

# %% [raw]
# dataframe.sort_index() # sort by rows asscending axis=0
# dataframe.sort_index(ascending=False) # sort by rows asscending axis=0
# dataframe.sort_index(axis=1) # Sort Columns names
# dataframe.sort_index(axis=1, ascending=False) # Sort Columns names

# %%
df.sort_values(by='Course')
# Out:
#    ID    Name Course     Fee  total   A   B   C   D   E  percentage Grade
# 0   1     Ali    A.I  1500.0    202  63   1  35  74  29        40.4  Fail
# 1   2    Asif    A.I  1500.0    267  93  50   1  74  49        53.4     C
# 2   3   Hamza    A.I  3000.0    270  32  84  83  53  18        54.0     C
# 4   5     Ali    A.I  3000.0    294  69  35  62  95  33        58.8     C
# 3   4  Kashif   AIOT     NaN    237  12  39  67  26  93        47.4  Fail

# %%
df.sort_values(by='Course', ascending=False)
# Out:
#    ID    Name Course     Fee  total   A   B   C   D   E  percentage Grade
# 3   4  Kashif   AIOT     NaN    237  12  39  67  26  93        47.4  Fail
# 0   1     Ali    A.I  1500.0    202  63   1  35  74  29        40.4  Fail
# 1   2    Asif    A.I  1500.0    267  93  50   1  74  49        53.4     C
# 2   3   Hamza    A.I  3000.0    270  32  84  83  53  18        54.0     C
# 4   5     Ali    A.I  3000.0    294  69  35  62  95  33        58.8     C

# %%
df.sort_values(by=['Course','Name'], ascending=[False,True])
# Out:
#    ID    Name Course     Fee  total   A   B   C   D   E  percentage Grade
# 3   4  Kashif   AIOT     NaN    237  12  39  67  26  93        47.4  Fail
# 0   1     Ali    A.I  1500.0    202  63   1  35  74  29        40.4  Fail
# 4   5     Ali    A.I  3000.0    294  69  35  62  95  33        58.8     C
# 1   2    Asif    A.I  1500.0    267  93  50   1  74  49        53.4     C
# 2   3   Hamza    A.I  3000.0    270  32  84  83  53  18        54.0     C

# %%
def grade1 (x1,x2,x3,x4,x5):
    x = x1+x2+x3+x4+x5
    p = x*100/500
    
    if p>= 80: return 'A+'
    elif p>= 70 : return 'A'
    elif p>= 60 : return 'B'
    elif p>= 50 : return 'C'
    else: return 'Fail'
    
    
df1['Grade_1']=df1[["A","B","C","D","E"]].apply(lambda x:grade1(*x), axis=1)
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-88a2a8f13a1b> in <module>
#      10
#      11
# ---> 12 df1['Grade_1']=df1[["A","B","C","D","E"]].apply(lambda x:grade1(*x), axis=1)
#      13 df1
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
# ...
