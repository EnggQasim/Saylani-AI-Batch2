# %%
import numpy as np
import pandas as pd

# %%
# https://www.iban.com/currency-codes
# data_size = 5000
# transactions = pd.DataFrame({"CNIC": np.random.choice([14,6,19,21], size=(data_size)),
#                    "TransactionID":np.random.randint(1,2, size=(data_size)),
#                   "Transaction Date":pd.date_range('1690-01-01', periods=data_size, freq="M"),
#                    "Description":np.random.choice(["TopUP","IBFT","FT"], size=(data_size)),
#                             "Amount":np.random.randint(1,1000000, size=(data_size)),
#                             "City":np.random.choice(["Karachi","Islamabad","Lahore"], size=(data_size))})

data_size = 5000
transactions = pd.DataFrame({"CNIC": np.random.randint(1,1000, size=(data_size)),
                   "TransactionID":np.random.randint(1,2, size=(data_size)),
                  "Transaction Date":pd.date_range('1690-01-01', periods=data_size, freq="M"),
                   "Description":np.random.choice(["TopUP","IBFT","FT"], size=(data_size)),
                             "City":np.random.choice(["Karachi","Islamabad","Lahore"], size=(data_size)),
                            "Amount": np.random.randint(1,1000000, size=(data_size)),
                            "Currency":np.random.choice(['036',"051","104",'106'], size=(data_size))})
transactions
# Out:
#       CNIC  TransactionID Transaction Date Description       City  Amount  \
# 0      243              1       1690-01-31       TopUP    Karachi   19998
# 1      393              1       1690-02-28        IBFT  Islamabad  870320
# 2      480              1       1690-03-31        IBFT    Karachi  377565
# 3      183              1       1690-04-30        IBFT     Lahore  212876
# 4      651              1       1690-05-31          FT    Karachi  947617
# ...    ...            ...              ...         ...        ...     ...
# 4995   447              1       2106-04-30       TopUP    Karachi  149657
# 4996   572              1       2106-05-31       TopUP  Islamabad  911787
# 4997   540              1       2106-06-30        IBFT     Lahore  973299
# 4998   729              1       2106-07-31       TopUP     Lahore  550140
# 4999   762              1       2106-08-31          FT  Islamabad   37522
#
#      Currency
# 0         051
# 1         051
# 2         106
# 3         104
# 4         036
# ...       ...
# 4995      036
# 4996      106
# 4997      036
# 4998      051
# 4999      104
#
# [5000 rows x 7 columns]

# %%
df = pd.read_html("https://www.iban.com/currency-codes")[0]
df
# Out:
#                Country         Currency Code  Number
# 0          AFGHANISTAN          Afghani  AFN   971.0
# 1        ÅLAND ISLANDS             Euro  EUR   978.0
# 2              ALBANIA              Lek  ALL     8.0
# 3              ALGERIA   Algerian Dinar  DZD    12.0
# 4       AMERICAN SAMOA        US Dollar  USD   840.0
# ..                 ...              ...  ...     ...
# 263  WALLIS AND FUTUNA        CFP Franc  XPF   953.0
# 264     WESTERN SAHARA  Moroccan Dirham  MAD   504.0
# 265              YEMEN      Yemeni Rial  YER   886.0
# 266             ZAMBIA   Zambian Kwacha  ZMW   967.0
# 267           ZIMBABWE  Zimbabwe Dollar  ZWL   932.0
#
# [268 rows x 4 columns]

# %%
df[['Code','Number']]
# Out:
#     Code  Number
# 0    AFN   971.0
# 1    EUR   978.0
# 2    ALL     8.0
# 3    DZD    12.0
# 4    USD   840.0
# ..   ...     ...
# 263  XPF   953.0
# 264  MAD   504.0
# 265  YER   886.0
# 266  ZMW   967.0
# 267  ZWL   932.0
#
# [268 rows x 2 columns]

# %%
df.loc[df[''] <= 4, 'equal_or_lower_than_4?'] = 'True'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-ed5e2db7493f> in <module>
# ----> 1 df.loc[df[''] <= 4, 'equal_or_lower_than_4?'] = 'True'
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: ''

# %%
https://www.geeksforgeeks.org/ways-to-apply-an-if-condition-in-pandas-dataframe/

# %%
https://datatofish.com/if-condition-in-pandas-dataframe/

# %%
geeksforgeeks.org/currency-converter-in-python/
