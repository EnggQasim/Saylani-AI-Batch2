# %% [markdown]
# # Types of Operator
#
# - Arithmetic Operators
# - Comparison (Relational) Operators
# - Assignment Operators
# - Logical Operators
# - Bitwise Operators
# - Membership Operators
# - Identity Operators

# %% [markdown]
# ## Arithmetic Operators

# %% [raw]
# + Addition
# - Subtraction
# * Multiplication
# / Division
# // floor Division
# % Modulus
# ** Power

# %%
2 + 5
# Out:
# 7

# %%
2.0 + 5.0
# Out:
# 7.0

# %%
2 + 5.0
# Out:
# 7.0

# %%
"A" + "B"
# Out:
# 'AB'

# %%
["Hamza","Junaid"] + ["Abid","Konain"]
# Out:
# ['Hamza', 'Junaid', 'Abid', 'Konain']

# %%
("Hamza","Junaid") + ("Abid","Konain")
# Out:
# ('Hamza', 'Junaid', 'Abid', 'Konain')

# %%
{"A","B"} + {"C","D"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-8586a3546320> in <module>
# ----> 1 {"A","B"} + {"C","D"}
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
{8,4} + {8,4}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-35cdad83ce6b> in <module>
# ----> 1 {8,4} + {8,4}
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
{1:"A",2:"B"} + {3:"C",4:"D"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-e74b1a64a46c> in <module>
# ----> 1 {1:"A",2:"B"} + {3:"C",4:"D"}
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
5 - 2
# Out:
# 3

# %%
4.2 - 3
# Out:
# 1.2000000000000002

# %%
{5,6,8,7} - {6,7}
# Out:
# {5, 8}

# %%
{"A","B","C"} - {"B"}
# Out:
# {'A', 'C'}

# %%
[4,5]-[2,3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-42828d5eb300> in <module>
# ----> 1 [4,5]-[2,3]
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
2 * 4
# Out:
# 8

# %%
3.0 * 2
# Out:
# 6.0

# %%
"A" * 3
# Out:
# 'AAA'

# %%
["A"] * 3
# Out:
# ['A', 'A', 'A']

# %%
("aA") * 2
# Out:
# 'aAaA'

# %%
("aA",) * 2
# Out:
# ('aA', 'aA')

# %%
test  = ("aA")
type(test)
# Out:
# str

# %%
test  = {"aA"}
type(test)
# Out:
# set

# %%
("aA","bB") * 2
# Out:
# ('aA', 'bB', 'aA', 'bB')

# %%
12 / 4
# Out:
# 3.0

# %%
11 / 3
# Out:
# 3.6666666666666665

# %%
11 // 3
# Out:
# 3

# %% [raw]
#         3
#  3  ________
# ____|   11  |____
#         9
#     ----------
#         2   # Modulus

# %%
11 % 3
# Out:
# 2

# %%
2 ** 3 # 2 X 2 X 2 = 8
# Out:
# 8

# %%
"A" ** 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-fd5ff83180b5> in <module>
# ----> 1 "A" ** 2
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %% [markdown]
# ## Comparison (Relational) Operators

# %% [raw]
# ==
# >
# <
# >=
# <=
# !=, <>

# %%
2 == 2
# Out:
# True

# %%
2 === 2
# Out:
#   File "<ipython-input-35-2a378b616cf0>", line 1
#     2 === 2
#         ^
# SyntaxError: invalid syntax

# %%
2 == 2.0
# Out:
# True

# %%
2 == '2'
# Out:
# False

# %%
'A' == 'a'
# Out:
# False

# %%
5 > 3
# Out:
# True

# %%
5 > 5
# Out:
# False

# %%
5 >= 5 # 5 > 4
# Out:
# True

# %%
5 > 4
# Out:
# True

# %%
"A" > "B"
# Out:
# False

# %% [raw]
# A=65  -> Z=90
# a=97  -> z=122
# 0=48  -> 9=57

# %%
ord("a")
# Out:
# 97

# %%
ord("X")
# Out:
# 88

# %%
chr(65)
# Out:
# 'A'

# %%
3 < 4
# Out:
# True

# %%
3 <= 3
# Out:
# True

# %%
'qasim' != "Qasim"
# Out:
# True

# %%
4 <> 4
# Out:
#   File "<ipython-input-53-51257adbce18>", line 1
#     4 <> 4
#        ^
# SyntaxError: invalid syntax

# %%
2 != 4
# Out:
# True

# %% [markdown]
# # Assignment Operators

# %% [raw]
# =
# +=
# -=
# *=
# /=
# //=
# **=
# %=

# %%
a = 5
print(a)
# Out:
# 5

# %%
a = 5
a = 6
a = 7
print(a)
# Out:
# 7

# %%
a,a,a = 5,6,7
a
# Out:
# 7

# %%
a = 5;a = 6;a = 7;print(a)
# Out:
# 7

# %%
a = 1 # 1
a +=2 # 1 + 2 = 3
a +=3 # 3 + 3=6
a +=4 # 6 + 4 = 10
print(a)
# Out:
# 10

# %%
a = 1 #      1
a = a + 2 #  1 + 2 = 3
a = a + 3 #  3 + 3 = 6
a = a + 4 # 6 + 4 = 10
print(a)
# Out:
# 10

# %%
a = 1
a++
a
# Out:
#   File "<ipython-input-69-ced3118feedb>", line 2
#     a++
#        ^
# SyntaxError: invalid syntax

# %%
a = 100
a -=5
a -=5
a -=10
print(a)
# Out:
# 80

# %%
a = 1
a *= 2 # 1 *2
a *= 3 # 2 * 3 = 6
print(a)
# Out:
# 6

# %%
a = 100
a /= 2
a /= 2
print(a)
# Out:
# 25.0

# %%
a = 100
a //= 2
a //= 2
print(a)
# Out:
# 25

# %%
a = 21
a %= 5
print(a)
# Out:
# 1

# %%
a = 2
a **= 2
a **= 3
print(a)
# Out:
# 64

# %%
a = "A"
a += "B"
print(a)
# Out:
# AB

# %%
a = [1,2,3]
a +=[5,6]
print(a)
# Out:
# [1, 2, 3, 5, 6]

# %% [markdown]
# # Logical Operators

# %% [raw]
# and  &
# or   |
# not

# %%
True and True and True
# Out:
# True

# %%
True & True & True
# Out:
# True

# %%
True and False and True
# Out:
# False

# %%
user = input("UserName:")
password = input("Password")

user == "Admin" and password == "123"
#"Admin" == "Admin" and "123" == "123"
#       True         and       True
#                   True
# Out:
# UserName:Admin
# Passwordthoraghalt
# False

# %%
user = input("UserName:")
password = input("Password")

(user == "Admin") & (password == "123")
#"Admin" == "Admin" and "123" == "123"
#       True         and       True
#                   True
# Out:
# UserName:Admin
# Password123
# True

# %%
user = input("UserName:")
password = input("Password")

user == "Admin" and password == "123"
#"Qasim" == "Admin" and "123" == "123"
#       False        and       True
#                   False
# Out:
# UserName:Admin
# Passwordghlat
# False

# %%
True or True or False or False or True
# Out:
# True

# %%
True | True | False | False | True
# Out:
# True

# %%
False | False | False | False | False
# Out:
# False

# %%
user = "Qasim" # Qasim,Ali, Hamza
password = "123" # 123


(user == "Qasim" or \
 user== "Ali" or \
 user == "Hamza") and password=="123"
# Out:
# True

# %%
user = "a"
password = "123"

not (user=="Ali" and password=="123")
# Out:
# True

# %%
not(True)
# Out:
# False

# %%
not True
# Out:
# False

# %%
not(False)
# Out:
# True

# %% [markdown]
# # Bitwise Operators

# %% [raw]
# 8,  7,    6,    5,    4,    3,    2,    1,    0
# 2,  2,    2,    2,    2,    2,    2,    2,    2
# ===============================================
# 256,128,  64,   32,  16,     8,    4,    2,   1

# %%
00100001
# Out:
#   File "<ipython-input-86-24f635631c48>", line 1
#     00001110
#            ^
# SyntaxError: invalid token

# %% [raw]
# 28=11100
# 29=11101
# 35=100011
#
#
# 1010101
# Right side
# 11001
#
# 1  = 1
# 0  = 0
# 0  = 0
# 1  = 8
# 1  = 16
# 25

# %% [raw]
# &  and
# 11100
# 11101
# ------
# 11100

# %%
28 & 29
# Out:
# 28

# %%
29 & 28
# Out:
# 28

# %% [raw]
# |  or
#
# 11100
# 11101
# ------
# 11101

# %%
28 | 29
# Out:
# 29

# %% [raw]
# ^
#
# 11100
# 11101
# ------
# 00001

# %%
28 ^ 29
# Out:
# 1

# %%
~29
# Out:
# -30

# %%
~88
# Out:
# -89

# %%
~-80
# Out:
# 79

# %% [markdown]
# # Membership Operators

# %% [raw]
# in
# not in

# %%
names = ["Ali","Hamza","Junaid","Kashif"]
i = 0
while i < len(names):
    if names[i]=="Junaid":
        print(True)
        break
    i +=1
# Out:
# True

# %%
names = ["Ali","Hamza","Junaid","Kashif"]
"Kashif" in names
# Out:
# True

# %%
user = input("Text")
'pakistan' in user
# Out:
# Textpakistan
# True

# %%
'Qasim' not in user
# Out:
# True

# %%
user = input()
user = user.split()
user
# Out:
# pakistan abc opps
# ['pakistan', 'abc', 'opps']

# %% [markdown]
# # Identity Operators

# %%
a = '5'
b = 5
c = a

print(a is b)
print(a is c)
# Out:
# False
# True

# %%
print(id(a))
print(id(b))
print(id(c))
# Out:
# 1504038411056
# 140725273469456
# 1504038411056

# %%
id(a) == id(c)
# Out:
# True

# %% [markdown]
# # Control Flow
# if else elif

# %% [raw]
# old
# if (logic){
#     value_if_True
# }else{
#     value_if_False
# }
#
# PYTHON
#
# if logic:
#     value_if_True
# else:
#     value_if_False

# %%
if True:
    print("Pakistan")
else:
    print("Zinda bad")

# %%
if False:
    print("Pakistan")
    print("Pakistan")
    print("Pakistan")
else:
    print("Zinda bad")

# %%
user = input("User")
password = input("Pass")

if (user=="Ali" or user=="Hamza") and password=="123":
    print("Valid User!")
else:
    print("Invalid User")

# %%
user = input("User")
password = input("Pass")

if (user in ['Ali',"Hamza","Junaid"]) and password=="123":
    print("Valid User!")
else:
    print("Invalid User")
