# %%
import numpy as np

# %%
import cv2

# %%
img = cv2.imread('flowers.jpg',0)
img.shape
# Out:
# (1067, 1600)

# %%
arr = np.array(img)

# %%
arr
# Out:
# array([[115, 110, 108, ..., 108, 111, 116],
#        [106, 101,  99, ...,  96, 100, 105],
#        [104, 100,  97, ..., 100, 105, 111],
#        ...,
#        [202, 201, 199, ...,  72,  69,  73],
#        [202, 201, 199, ...,  66,  61,  65],
#        [206, 205, 204, ...,  78,  76,  81]], dtype=uint8)

# %%
( (1067)/2 ,(1600)/2 )
# Out:
# (533.5, 800.0)

# %%
crop = arr[220:530 , 530:1200]

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook
plt.imshow(crop)
# Out:
# <img src="data:image/png;base64,..." width="640">
