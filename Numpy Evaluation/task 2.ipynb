# %%
import cv2

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
import numpy as np

# %%
img1 = cv2.imread('flowers 1.jpg',0)

# %%
img1.shape
# Out:
# (865, 1300)

# %%
print(img1)
# Out:
# [[146 146 147 ... 162 161 160]
#  [146 147 147 ... 162 161 160]
#  [146 147 148 ... 161 160 159]
#  ...
#  [160 172 180 ...  36  36  36]
#  [138 156 170 ...  37  37  37]
#  [106 134 153 ...  36  36  36]]

# %%
img1_crop = img1[0:500,0:500]

# %%
plt.imshow(img1_crop)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
img2 = cv2.imread('flowers 2.jpg',0)

# %%
img2.shape
# Out:
# (667, 1000)

# %%
print(img2)
# Out:
# [[ 92  92  91 ...  18  18  17]
#  [ 90  88  87 ...  18  18  18]
#  [ 87  85  83 ...  18  18  18]
#  ...
#  [ 78  79  80 ... 171 170 170]
#  [ 78  79  80 ... 171 170 170]
#  [ 78  79  80 ... 171 170 170]]

# %%
img2_crop = img2[0:500,0:500]

# %%
plt.imshow(img2_crop)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
combine = np.hstack((img1_crop, img2_crop))
plt.imshow(combine)
# Out:
# <img src="data:image/png;base64,..." width="640">
